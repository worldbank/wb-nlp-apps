# %% [markdown]
# # Get country icons

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.nationsonline.org/oneworld/country_code_list.htm'
page = requests.get(url)

# %%
bsoup = BeautifulSoup(page.content, 'html5lib')

# %%
bsoup.find_all('td')
# Out:
# [<td> </td>,
#  <td class="abs" colspan="4"><br/><a class="anchor" id="A"><strong>A</strong></a></td>,
#  <td><div class="flag" id="AFG"></div></td>,
#  <td class="abs"><a href="afghanistan.htm">Afghanistan</a></td>,
#  <td style="text-align:center"> AF</td>,
#  <td style="text-align:center">AFG</td>,
#  <td style="text-align:center">004</td>,
#  <td><img alt="ALA" height="12" src="../flags/Aland12_flag.gif" width="20"/></td>,
#  <td class="abs"><em>Aland Islands</em></td>,
#  <td style="text-align:center">AX</td>,
#  <td style="text-align:center">ALA</td>,
#  <td style="text-align:center">248</td>,
#  <td><div class="flag" id="ALB"></div></td>,
#  <td class="abs"><a href="albania.htm">Albania</a></td>,
#  <td style="text-align:center">AL</td>,
#  <td style="text-align:center">ALB</td>,
#  <td style="text-align:center">008</td>,
#  <td><div class="flag" id="DZA"></div></td>,
#  <td class="abs"><a href="algeria.htm">Algeria</a></td>,
#  <td style="text-align:center">DZ</td>,
# ...

# %%
request.post('wbes2474:8910/api/lda_docs_by_topic_composition', data={'model_id': 'WB', 'corpus_id': 'ALL_50', 'topn': 5
                                                                     .,})

{'model_id': 'WB', 'corpus_id': 'ALL_50', 'topn': 5, 'topic_percentage': {0:0.25, 8:0.1}}
