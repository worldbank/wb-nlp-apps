# %%
# %%capture

# get_corpus_path
# get_txt_orig_path

# %run ../path_manager.ipynb


# AcronymMapper
# %run ./AcronymModule.ipynb

# %%
acronym_mapper = AcronymMapper(whitelist_file='../whitelists/whitelist_acronyms_imf.csv', sim_thresh=0.8)

# %%
get_txt_orig_path('IMF')
# Out:
# '/R/NLP/CORPUS/IMF/TXT_ORIG'

# %%
corpus_id = 'IMF'
sample_file = 'imf_00ae75cce82e5c915d5bead7a7bb2165e9ef215a.txt'
# sample_file = os.path.join(get_txt_orig_path(corpus_id), sample_file)

# %%
# %%time
expanded_doc = acronym_mapper.expand_doc_acronyms_in_file(sample_file)
# Out:
# CPU times: user 106 ms, sys: 4 ms, total: 110 ms
# Wall time: 108 ms

# %%
acronym_mapper.get_valid_doc_acronym(doc)
# Out:
# ({'ADF': 'African Development Fund',
#   'CAS': 'Country Assistance Strategy',
#   'HIPC': 'Heavily Indebted Poor Countries',
#   'IFRS': 'International Financial Reporting Standards',
#   'IMF': 'International Monetary Fund',
#   'MDRI': 'Multilateral Debt Relief Initiative',
#   'NPV': 'Net Present Value',
#   'PRGF': 'Poverty Reduction Growth Facility',
#   'PRSP': 'Poverty Reduction Strategy Paper'},
#  {'Poverty Reduction and Growth Facility': 'Poverty Reduction Growth Facility'})

# %%
print(expanded_doc)
# Out:
# Niger: Second Review Under the Three-Year Arrangement Under the Poverty Reduction Growth Facility and Request for Waiver of Performance Criteria--Staff Report; Press Release; and Statement by the Executive Director; International Monetary Fund Country Report 06/258; June 5, 2006
#
#
#  © 2006  International Monetary Fund July 2006
#     International Monetary Fund Country Report No. 06/258
#
#
#  January 29, 2001 September 24,
#
# 2001
# January 29, 2001
#
# Niger: Second Review Under the Three-Year Arrangement Under the Poverty
# Reduction and Growth Facility and Request for Waiver of Performance Criteria—Staff
# Report; Press Release on the Executive Board Discussion; and Statement by the
# Executive Director for Niger
#
# In the context of the second review under the three-year arrangement under the Poverty Reduction
# and Growth Facility and request for a waiver of performance criteria, the following documents have
# been released and are included in this package:
#
# ...

# %%
acronym_mapper.get_valid_doc_acronym(txt)
# Out:
# ({'ADF': 'African Development Fund',
#   'BCEAO': 'Central Bank West African States',
#   'CAS': 'Country Assistance Strategy',
#   'HIPC': 'Heavily Indebted Poor Countries',
#   'IFRS': 'International Financial Reporting Standards',
#   'IMF': 'International Monetary Fund',
#   'MDRI': 'Multilateral Debt Relief Initiative',
#   'PRGF': 'Poverty Reduction Growth Facility',
#   'WAEMU': 'West African Economic Monetary Union'},
#  {})
